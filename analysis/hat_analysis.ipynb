# %% [markdown]
# # HAT Indicator Analysis — Emotional vs Neutral Inference
#
# **Purpose:** Analyse which hardware indicators discriminate between neutral and
# emotional LLM inference trials, structured around the HAT definition.
#
# **Structure:**
# - §1 Imports and configuration
# - §2 Load data (per-run + combined)
# - §3 Confounder check (elapsed_ms balance)
# - §4 Indicator taxonomy — classify every column
# - §5 Layer 1 analysis — genuine hardware anomaly indicators
# - §6 Layer 2 analysis — continuous performance metrics
# - §7 Confounder summary — shown separately, not used in clustering
# - §8 Multi-feature clustering — top N features from L1 + L2 combined
#
# Each section answers: *does this indicator fire, does it differ between conditions,
# and how well does it separate neutral from emotional trials?*

# %% [markdown]
# ## §1 — Imports

# %%
import warnings
from pathlib import Path
from collections import defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import scipy.stats as sp_stats
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, confusion_matrix
from sklearn.decomposition import PCA

warnings.filterwarnings('ignore')
plt.rcParams['figure.dpi'] = 120
plt.rcParams['figure.figsize'] = (14, 5)
print('Imports OK')
# Out:
# Imports OK

# %% [markdown]
# ## §2 — Configuration

# %%
# ── Paths ─────────────────────────────────────────────────────────────────────
BASE_DIR   = Path.home() / 'Desktop' / 'mccviahat'
DATA_DIR   = BASE_DIR / 'data' / 'clemsonc6420'
RESULT_DIR = BASE_DIR / 'results' / 'hat_analysis'
RESULT_DIR.mkdir(parents=True, exist_ok=True)

assert BASE_DIR.exists(), f'Repo root not found: {BASE_DIR}'

# ── Runs to load ──────────────────────────────────────────────────────────────
# Add or remove run labels here as new data arrives
RUNS = ['A', 'B', 'D', 'E', 'F', 'AA', 'AB', 'AC', '1', '2', '3', '4']


# ── n-D clustering config ─────────────────────────────────────────────────────
# Number of top features (by composite rank) to use in the multi-feature KMeans
TOP_N = 4 # <-- change this

# ── Layer 1 indicators (HAT definition named types) ───────────────────────────
# These come from /proc/interrupts (hat_ prefix) and perf tracepoints
HAT_L1 = {
    'hat_SPU':            'Spurious interrupt',
    'hat_MCE':            'Machine Check Exception',
    'hat_TLB':            'TLB Shootdown (IPI)',
    'tlb:tlb_flush':      'TLB Shootdown (tracepoint, 1ms)',
    'mce:mce_record':     'MCE tracepoint',
    'core_power.throttle':'Thermal/Power Anomaly',
    'uncore_imc/UNC_M_ECC_CORRECTABLE_ERRORS/': 'ECC Correctable Error',
}

# ── Layer 2 indicators (continuous performance metrics) ───────────────────────
HAT_L2 = {
    'uncore_imc/cas_count_read/':  'DRAM read bandwidth (CAS)',
    'uncore_imc/cas_count_write/': 'DRAM write bandwidth (CAS)',
    'dTLB-load-misses':   'dTLB load misses (weight tensor pressure)',
    'cache-misses':        'LLC cache misses → DRAM fetches',
    'cache-references':    'LLC cache references',
    'LLC-load-misses':     'LLC load misses',
    'cycles':              'CPU cycles',
    'instructions':        'Retired instructions',
    'stalled-cycles-frontend': 'Frontend pipeline stalls',
    'stalled-cycles-backend':  'Backend pipeline stalls',
    'branch-misses':       'Branch mispredictions',
    'branch-instructions': 'Total branches',
    'power/energy-pkg/':   'Package energy (RAPL)',
    'power/energy-ram/':   'DRAM energy (RAPL)',
    'msr/cpu_thermal_margin/': 'Thermal margin (°C below Tj_max)',
}

# ── Confounder indicators (collected for context, NOT used in clustering) ──────
CONFOUNDERS = {
    'context-switches': 'Context switches (scheduling artefact)',
    'cpu-migrations':   'CPU migrations (load balancer)',
    'page-faults':      'Page faults (mmap / memory management)',
    'cpu-clock':        'CPU time (duration normaliser)',
    'cpu_freq_mean':    'CPU frequency mean (DVFS governor)',
}

# ── Indicators to exclude from all analysis ────────────────────────────────────
EXCLUDE_INDICATORS = {
    'hat_PMI', 'hat_NMI',   # perf's own sampling interrupts — artefact
    'hat_LOC', 'hat_RES', 'hat_CAL', 'hat_MCP',  # fixed-rate OS housekeeping
}

ALL_METRICS = [
    'mean_rate', 'variance', 'p90_p10', 'slope',
    'spectral_entropy', 'iat_cv', 'burst_rate',
    'burst_clustering', 'lz_complexity', 'perm_entropy'
]

print(f'Configuration OK')
print(f'  Runs: {RUNS}')
print(f'  TOP_N for n-D clustering: {TOP_N}')
print(f'  L1 indicators: {len(HAT_L1)}')
print(f'  L2 indicators: {len(HAT_L2)}')
print(f'  Confounders:   {len(CONFOUNDERS)}')
# Out:
# Configuration OK
#   Runs: ['A', 'B', 'D', 'E', 'F', 'AA', 'AB', 'AC', '1', '2', '3', '4']
#   TOP_N for n-D clustering: 4
#   L1 indicators: 7
#   L2 indicators: 15
#   Confounders:   5

# %% [markdown]
# ## §3 — Load data

# %%
dfs_by_run = {}
loaded, missing = [], []

for run in RUNS:
    p = DATA_DIR / f'independent{run}.csv'
    if p.exists():
        df = pd.read_csv(p)
        df['run'] = run
        dfs_by_run[run] = df
        loaded.append(run)
    else:
        missing.append(run)

if missing:
    print(f'⚠  Not found (skipping): {missing}')

RUNS_LOADED = loaded
df_all = pd.concat([dfs_by_run[r] for r in RUNS_LOADED], ignore_index=True)
y      = (df_all['condition'] == 'emotional').astype(int).values

print(f'Loaded {len(RUNS_LOADED)} runs: {RUNS_LOADED}')
print(f'  Total trials : {len(df_all)}')
print(f'  Neutral      : {(df_all.condition == "neutral").sum()}')
print(f'  Emotional    : {(df_all.condition == "emotional").sum()}')
print(f'  Run counts   : {df_all["run"].value_counts().sort_index().to_dict()}')
print(f'  Feature cols : {len([c for c in df_all.columns if "__" in c])}')
# Out:
# Loaded 12 runs: ['A', 'B', 'D', 'E', 'F', 'AA', 'AB', 'AC', '1', '2', '3', '4']
#   Total trials : 480
#   Neutral      : 240
#   Emotional    : 240
#   Run counts   : {'1': 40, '2': 40, '3': 40, '4': 40, 'A': 40, 'AA': 40, 'AB': 40, 'AC': 40, 'B': 40, 'D': 40, 'E': 40, 'F': 40}
#   Feature cols : 580

# %% [markdown]
# ## §4 — Confounder check: elapsed_ms
#
# If emotional and neutral prompts take significantly different amounts of time,
# any metric that scales with duration is confounded. We check this first.

# %%
df_all['elapsed_ms'] = pd.to_numeric(df_all['elapsed_ms'], errors='coerce')
dur_n = df_all.loc[df_all.condition == 'neutral',   'elapsed_ms'].dropna().values
dur_e = df_all.loc[df_all.condition == 'emotional', 'elapsed_ms'].dropna().values

stat, p_dur = sp_stats.mannwhitneyu(dur_n, dur_e, alternative='two-sided')

print(f'Neutral   elapsed_ms: mean={dur_n.mean():.0f}ms  median={np.median(dur_n):.0f}ms  n={len(dur_n)}')
print(f'Emotional elapsed_ms: mean={dur_e.mean():.0f}ms  median={np.median(dur_e):.0f}ms  n={len(dur_e)}')
print(f'MWU p={p_dur:.4f}  →  {"⚠ SIGNIFICANT — length-confounded metrics are unreliable" if p_dur < 0.05 else "✓ balanced — no length confound"}')

LENGTH_CONFOUNDED = p_dur < 0.05

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
bins = np.linspace(min(dur_n.min(), dur_e.min()), max(dur_n.max(), dur_e.max()), 30)
for ax, vals, color, label in [(axes[0], dur_n, 'steelblue', 'Neutral'),
                                (axes[1], dur_e, 'firebrick', 'Emotional')]:
    ax.hist(vals, bins=bins, color=color, alpha=0.85)
    ax.set_title(f'elapsed_ms — {label}')
    ax.set_xlabel('ms')
    ax.axvline(np.median(vals), color='black', lw=1.5, ls='--', label=f'median={np.median(vals):.0f}')
    ax.legend(fontsize=9)
plt.suptitle(f'Inference duration distribution  (MWU p={p_dur:.4f})', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Neutral   elapsed_ms: mean=22574ms  median=22598ms  n=240
# Emotional elapsed_ms: mean=22727ms  median=22770ms  n=240
# MWU p=0.0717  →  ✓ balanced — no length confound

# %% [markdown]
# ## §5 — Indicator taxonomy
#
# Every column in the feature matrix is assigned to one of four categories:
# - **Layer 1** — named HAT hardware anomaly indicators
# - **Layer 2** — continuous performance metrics
# - **Confounder** — scheduling/duration artefacts (shown separately, never clustered)
# - **Excluded** — measurement artefacts (perf's own activity, fixed-rate OS timers)
#
# This cell builds those groups and reports what is present in this dataset.

# %%
def indicator_of(col): return col.split('__', 1)[0]
def metric_of(col):    return col.split('__', 1)[1] if '__' in col else ''

all_feat_cols = [c for c in df_all.columns if '__' in c]

l1_cols, l2_cols, conf_cols, excl_cols, other_cols = [], [], [], [], []
for col in all_feat_cols:
    ind = indicator_of(col)
    if ind in EXCLUDE_INDICATORS:
        excl_cols.append(col)
    elif any(ind == k or ind.startswith(k) for k in HAT_L1):
        l1_cols.append(col)
    elif any(ind == k or ind.startswith(k) for k in HAT_L2):
        l2_cols.append(col)
    elif any(ind == k or ind.startswith(k) for k in CONFOUNDERS):
        conf_cols.append(col)
    else:
        other_cols.append(col)

print(f'Feature column taxonomy ({len(all_feat_cols)} total):')
print(f'  Layer 1  (HAT anomaly indicators) : {len(l1_cols):4d}')
print(f'  Layer 2  (continuous metrics)     : {len(l2_cols):4d}')
print(f'  Confounders                        : {len(conf_cols):4d}')
print(f'  Excluded (artefacts)               : {len(excl_cols):4d}')
print(f'  Other (not in taxonomy)            : {len(other_cols):4d}')
if other_cols:
    inds = sorted(set(indicator_of(c) for c in other_cols))
    print(f'    Other indicators: {inds}')

# Build clean feature matrices (standardised, NaN filled)
META_COLS = {'condition','prompt_index','elapsed_ms','dur_s','n_tokens','title','run'}

def make_matrix(cols):
    df = df_all[cols].apply(pd.to_numeric, errors='coerce')
    df = df.loc[:, df.std() > 0]          # drop zero-variance
    df = df.fillna(df.median())            # fill NaN with median
    scaler = StandardScaler()
    return df, pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

X_l1_raw, X_l1 = make_matrix([c for c in l1_cols   if indicator_of(c) not in EXCLUDE_INDICATORS])
X_l2_raw, X_l2 = make_matrix([c for c in l2_cols   if indicator_of(c) not in EXCLUDE_INDICATORS])
X_cf_raw, X_cf = make_matrix([c for c in conf_cols  if indicator_of(c) not in EXCLUDE_INDICATORS])

print(f'\nFeature matrices after cleaning:')
print(f'  L1 : {X_l1.shape}')
print(f'  L2 : {X_l2.shape}')
print(f'  CF : {X_cf.shape}')
# Out:
# Feature column taxonomy (580 total):
#   Layer 1  (HAT anomaly indicators) :   70
#   Layer 2  (continuous metrics)     :  150
#   Confounders                        :   50
#   Excluded (artefacts)               :   60
#   Other (not in taxonomy)            :  250
#     Other indicators: ['hat_BLOCK', 'hat_DFR', 'hat_ERR', 'hat_HI', 'hat_HRTIMER', 'hat_IRQ_POLL', 'hat_IWI', 'hat_MIS', 'hat_NET_RX', 'hat_NET_TX', 'hat_NPI', 'hat_PIN', 'hat_PIW', 'hat_RCU', 'hat_RTR', 'hat_SCHED', 'hat_TASKLET', 'hat_THR', 'hat_TIMER', 'hat_TRM', 'irq:irq_handler_entry', 'irq:irq_handler_exit', 'irq:softirq_entry', 'irq:softirq_exit', 'irq:softirq_raise']
#
# Feature matrices after cleaning:
#   L1 : (480, 34)
#   L2 : (480, 117)
#   CF : (480, 46)

# %% [markdown]
# ## §6 — Helper functions (run once)

# %%
from scipy.stats import mannwhitneyu

def mwu(col, raw_df):
    """Return (p, effect_r, direction, n_neutral, n_emotional) for one column."""
    n_vals = raw_df.loc[df_all.condition == 'neutral',   col].dropna()
    e_vals = raw_df.loc[df_all.condition == 'emotional', col].dropna()
    if len(n_vals) < 3 or len(e_vals) < 3:
        return np.nan, np.nan, '—', len(n_vals), len(e_vals)
    stat, p = mannwhitneyu(n_vals, e_vals, alternative='two-sided')
    r = 1 - 2*stat/(len(n_vals)*len(e_vals))
    direction = '↑E' if e_vals.mean() > n_vals.mean() else '↓E'
    return p, r, direction, len(n_vals), len(e_vals)

def kmeans1d(col, raw_df):
    """1-D KMeans k=2 on one column. Returns (ari, acc, n_errors)."""
    vals = raw_df[col].dropna().values.reshape(-1, 1)
    if len(vals) < 6:
        return np.nan, np.nan, np.nan
    km = KMeans(n_clusters=2, n_init=20, random_state=42).fit(vals)
    labels = km.labels_
    ari = adjusted_rand_score(y, labels)
    # Align cluster labels to ground truth (try both assignments)
    cm1 = confusion_matrix(y, labels)
    acc1 = (cm1[0,0] + cm1[1,1]) / cm1.sum()
    acc2 = (cm1[0,1] + cm1[1,0]) / cm1.sum()
    acc  = max(acc1, acc2)
    n_err = int(round((1 - acc) * len(y)))
    return ari, acc, n_err

def analyse_indicator_group(group_name, ind_dict, X_raw, title_color='steelblue'):
    """
    For each indicator in ind_dict, across all its metrics:
      - check if it fires (non-zero trials)
      - MWU p-value and effect size
      - 1-D KMeans ARI and error count
    Returns a summary DataFrame sorted by best composite rank.
    """
    rows = []
    for ind, description in ind_dict.items():
        # Find columns for this indicator in X_raw
        ind_cols = [c for c in X_raw.columns if indicator_of(c) == ind]
        if not ind_cols:
            # Check with prefix match (for uncore_imc/ style names)
            ind_cols = [c for c in X_raw.columns if c.startswith(ind + '__')]
        if not ind_cols:
            rows.append({'indicator': ind, 'description': description,
                         'metric': '—', 'nonzero_trials': 0, 'total_trials': len(df_all),
                         'status': 'NOT IN DATA',
                         'p': np.nan, 'effect_r': np.nan, 'direction': '—',
                         'ari': np.nan, 'acc': np.nan, 'n_errors': np.nan})
            continue

        for col in ind_cols:
            metric = metric_of(col)
            vals = X_raw[col].dropna()
            nonzero = (vals.abs() > 1e-9).sum()
            total   = len(vals)
            all_zero = nonzero == 0

            if all_zero:
                rows.append({'indicator': ind, 'description': description,
                             'metric': metric, 'nonzero_trials': 0, 'total_trials': total,
                             'status': 'ALL ZERO',
                             'p': np.nan, 'effect_r': np.nan, 'direction': '—',
                             'ari': np.nan, 'acc': np.nan, 'n_errors': np.nan})
                continue

            p, r, direction, nn, ne = mwu(col, X_raw)
            ari, acc, n_err = kmeans1d(col, X_raw)
            star = '★' if (pd.notna(p) and p < 0.05) else ''
            rows.append({'indicator': ind, 'description': description,
                         'metric': metric, 'nonzero_trials': nonzero, 'total_trials': total,
                         'status': f'p={p:.3f}{star}' if pd.notna(p) else 'INSUFF',
                         'p': p, 'effect_r': r, 'direction': direction,
                         'ari': ari, 'acc': acc, 'n_errors': n_err,
                         'col': col})

    df_res = pd.DataFrame(rows)
    return df_res

def print_summary_table(df_res, title):
    print(f'\n{"="*90}')
    print(f'  {title}')
    print(f'{"="*90}')
    print(f'  {"Indicator":<40} {"Metric":<22} {"NonZero":>7} {"p-value":>10} {"Dir":>4} {"ARI":>7} {"Errors":>7}')
    print(f'  {"-"*95}')
    prev_ind = None
    for _, r in df_res.iterrows():
        if r['indicator'] != prev_ind:
            print()
            prev_ind = r['indicator']
        nz = f"{int(r['nonzero_trials'])}/{int(r['total_trials'])}" if pd.notna(r['nonzero_trials']) else '—'
        pv = f"{r['p']:.4f}" if pd.notna(r['p']) else '—'
        star = '★' if pd.notna(r['p']) and r['p'] < 0.05 else ' '
        ari  = f"{r['ari']:.3f}" if pd.notna(r['ari']) else '—'
        err  = f"{int(r['n_errors'])}" if pd.notna(r['n_errors']) else '—'
        print(f"  {r['indicator']:<40} {r['metric']:<22} {nz:>7} {pv:>9}{star} {r['direction']:>4} {ari:>7} {err:>7}")

print('Helper functions defined.')
# Out:
# Helper functions defined.

# %% [markdown]
# ## §7 — Layer 1: HAT hardware anomaly indicators
#
# These are the indicators the HAT definition names explicitly. For each one we report:
# - **Non-zero trials**: how many of the trials saw any events at all
# - **MWU p-value**: does the distribution differ between neutral and emotional?
# - **1-D KMeans**: if we cluster trials on this one feature alone, how many errors?
#
# **Expected result on a healthy node:** SPU, MCE, ECC = zero. TLB Shootdown should
# have actual values since the LLM's weight tensors generate VM pressure.

# %%
l1_results = analyse_indicator_group('Layer 1', HAT_L1, X_l1_raw)
print_summary_table(l1_results, 'Layer 1 — HAT Hardware Anomaly Indicators')

# Save for later use in n-D clustering
l1_results.to_csv(RESULT_DIR / 'l1_results.csv', index=False)
# Out:
# ==========================================================================================
#   Layer 1 — HAT Hardware Anomaly Indicators
# ==========================================================================================
#   Indicator                                Metric                 NonZero    p-value  Dir     ARI  Errors
#   -----------------------------------------------------------------------------------------------
#
#   hat_SPU                                  lz_complexity          480/480    0.1858    ↓E   0.000     229
#
#   hat_MCE                                  lz_complexity          480/480    0.1858    ↓E   0.000     229
#
#   hat_TLB                                  mean_rate              480/480    0.0593    ↓E   0.001     227
#   hat_TLB                                  variance               480/480    0.1062    ↓E  -0.001     235
#   hat_TLB                                  p90_p10                480/480    0.0912    ↑E  -0.001     239
#   hat_TLB                                  slope                  480/480    0.1034    ↑E  -0.001     234
#   hat_TLB                                  spectral_entropy       480/480    0.7850    ↑E  -0.001     232
#   hat_TLB                                  iat_cv                 480/480    0.8484    ↑E  -0.002     239
#   hat_TLB                                  burst_rate             480/480    0.3986    ↓E   0.002     225
#   hat_TLB                                  burst_clustering       480/480    0.3950    ↓E   0.001     231
#   hat_TLB                                  lz_complexity          480/480    0.2929    ↑E   0.001     228
#   hat_TLB                                  perm_entropy           480/480    0.4234    ↓E  -0.000     232
#
#   tlb:tlb_flush                            mean_rate              480/480    0.0312★   ↓E   0.000     229
#   tlb:tlb_flush                            variance               480/480    0.1382    ↓E  -0.001     237
#   tlb:tlb_flush                            p90_p10                480/480    0.1588    ↓E   0.000     239
#   tlb:tlb_flush                            slope                  480/480    0.0773    ↑E   0.001     227
#   tlb:tlb_flush                            spectral_entropy       480/480    0.2913    ↑E  -0.001     232
#   tlb:tlb_flush                            iat_cv                 471/480    0.5414    ↑E   0.000     229
#   tlb:tlb_flush                            burst_rate             480/480    0.8541    ↑E   0.002     229
#   tlb:tlb_flush                            burst_clustering       480/480    0.0736    ↓E   0.003     223
#   tlb:tlb_flush                            lz_complexity          480/480    0.2919    ↓E  -0.001     232
#   tlb:tlb_flush                            perm_entropy           480/480    0.1205    ↓E  -0.001     234
#
#   mce:mce_record                           lz_complexity          480/480    0.5956    ↓E  -0.002     236
#
#   core_power.throttle                      mean_rate              480/480    0.0929    ↓E   0.006     219
#   core_power.throttle                      variance               480/480    0.6251    ↓E  -0.001     233
#   core_power.throttle                      p90_p10                480/480    0.3608    ↓E  -0.002     240
#   core_power.throttle                      slope                  480/480    0.0466★   ↓E  -0.000     231
#   core_power.throttle                      spectral_entropy       480/480    0.1292    ↑E   0.005     220
#   core_power.throttle                      iat_cv                   7/480    0.7072    ↓E  -0.000     239
#   core_power.throttle                      burst_rate             480/480    0.2967    ↓E   0.001     227
#   core_power.throttle                      burst_clustering       480/480    0.5901    ↓E   0.001     228
#   core_power.throttle                      lz_complexity          480/480    0.0903    ↑E  -0.000     240
#   core_power.throttle                      perm_entropy           480/480    0.6753    ↓E  -0.002     237
#
#   uncore_imc/UNC_M_ECC_CORRECTABLE_ERRORS/ lz_complexity          480/480    0.5170    ↑E  -0.000     240

# %% [markdown]
# ### §7a — Layer 1: firing rate summary

# %%
# For each L1 indicator: how many trials had ANY non-zero reading (any metric)?
print('\nFiring rate per L1 indicator (any metric non-zero):')
print(f'  {"Indicator":<45} {"HAT type":<35} {"Non-zero trials":>15}')
print(f'  {"-"*100}')
for ind, desc in HAT_L1.items():
    ind_cols = [c for c in X_l1_raw.columns
                if indicator_of(c) == ind or c.startswith(ind + '__')]
    if not ind_cols:
        print(f'  {ind:<45} {desc:<35} {"NOT IN DATA":>15}')
        continue
    # A trial is non-zero if ANY of its metrics is non-zero
    any_nonzero = (X_l1_raw[ind_cols].apply(pd.to_numeric, errors='coerce').abs() > 1e-9).any(axis=1)
    n_nonzero   = any_nonzero.sum()
    n_total     = len(any_nonzero)
    pct = 100 * n_nonzero / n_total
    tag = 'ALL ZERO ✓ (healthy)' if n_nonzero == 0 else f'{n_nonzero}/{n_total} ({pct:.0f}%)'
    print(f'  {ind:<45} {desc:<35} {tag:>15}')
# Out:
# Firing rate per L1 indicator (any metric non-zero):
#   Indicator                                     HAT type                            Non-zero trials
#   ----------------------------------------------------------------------------------------------------
#   hat_SPU                                       Spurious interrupt                   480/480 (100%)
#   hat_MCE                                       Machine Check Exception              480/480 (100%)
#   hat_TLB                                       TLB Shootdown (IPI)                  480/480 (100%)
#   tlb:tlb_flush                                 TLB Shootdown (tracepoint, 1ms)      480/480 (100%)
#   mce:mce_record                                MCE tracepoint                       480/480 (100%)
#   core_power.throttle                           Thermal/Power Anomaly                480/480 (100%)
#   uncore_imc/UNC_M_ECC_CORRECTABLE_ERRORS/      ECC Correctable Error                480/480 (100%)

# %% [markdown]
# ### §7b — Layer 1: strip plots for non-zero indicators

# %%
# Strip plots for L1 indicators that have actual values
# Use the metric with the lowest p-value for each indicator
rng = np.random.default_rng(42)

l1_has_signal = l1_results[
    (l1_results.nonzero_trials > 0) &
    (l1_results.status != 'NOT IN DATA') &
    (l1_results.status != 'ALL ZERO')
].copy()

if l1_has_signal.empty:
    print('All Layer 1 indicators are zero — healthy node confirmed.')
    print('No strip plots to show.')
else:
    # For each indicator, pick the best metric (lowest p)
    best_l1 = (l1_has_signal
               .dropna(subset=['p'])
               .sort_values('p')
               .drop_duplicates(subset=['indicator'])
               .reset_index(drop=True))

    n_plots = len(best_l1)
    fig, axes = plt.subplots(1, n_plots, figsize=(5 * n_plots, 5))
    if n_plots == 1: axes = [axes]

    for ax, (_, row) in zip(axes, best_l1.iterrows()):
        col = row['col']
        n_vals = X_l1_raw.loc[df_all.condition == 'neutral',   col].dropna().values
        e_vals = X_l1_raw.loc[df_all.condition == 'emotional', col].dropna().values

        for x_pos, vals, color in [(0, n_vals, 'steelblue'), (1, e_vals, 'firebrick')]:
            jitter = rng.uniform(-0.18, 0.18, len(vals))
            ax.scatter(np.full(len(vals), x_pos) + jitter, vals,
                       color=color, alpha=0.6, s=28, zorder=3)
            ax.plot([x_pos-0.22, x_pos+0.22], [np.median(vals)]*2,
                    color=color, lw=2.5, zorder=4)

        ax.set_xticks([0,1])
        ax.set_xticklabels([f'N\n(n={len(n_vals)})', f'E\n(n={len(e_vals)})'], fontsize=10)
        ax.set_title(f"{row['indicator']}\nbest metric: {row['metric']}", fontsize=10)
        ax.set_ylabel(row['metric'], fontsize=9)
        ax.spines[['top','right']].set_visible(False)

        p_str = f"p={row['p']:.3f}" if pd.notna(row['p']) else 'p=—'
        ari_str = f"ARI={row['ari']:.3f}" if pd.notna(row['ari']) else 'ARI=—'
        err_str = f"errors={int(row['n_errors'])}" if pd.notna(row['n_errors']) else ''
        ax.text(0.04, 0.97, f"{p_str}\n{ari_str}\n{err_str}\n{row['direction']}",
                transform=ax.transAxes, ha='left', va='top', fontsize=9,
                bbox=dict(facecolor='white', alpha=0.85, edgecolor='#ccc', boxstyle='round'))

    handles = [mpatches.Patch(color=c, label=l)
               for c, l in [('steelblue','Neutral'), ('firebrick','Emotional')]]
    fig.legend(handles=handles, loc='upper right', fontsize=10)
    plt.suptitle('Layer 1 — strip plots (best metric per indicator)', fontsize=13, y=1.02)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### §7c — Layer 1: 1-D KMeans heatmap (ARI across all metrics)

# %%
# Heatmap: indicator × metric, coloured by ARI, annotated with direction + star
l1_ok = l1_results[l1_results.status.ne('NOT IN DATA') & l1_results.status.ne('ALL ZERO')].copy()

if l1_ok.empty:
    print('No non-zero L1 features — nothing to plot.')
else:
    inds    = l1_ok['indicator'].unique().tolist()
    metrics = ALL_METRICS
    ari_grid = np.full((len(inds), len(metrics)), np.nan)
    dir_grid = np.full((len(inds), len(metrics)), '—', dtype=object)
    p_grid   = np.full((len(inds), len(metrics)), np.nan)

    for _, row in l1_ok.iterrows():
        if row['metric'] in metrics:
            i = inds.index(row['indicator'])
            j = metrics.index(row['metric'])
            ari_grid[i, j] = row['ari'] if pd.notna(row['ari']) else np.nan
            dir_grid[i, j] = row['direction']
            p_grid[i, j]   = row['p']

    ari_masked = np.ma.masked_invalid(ari_grid)
    fig, ax = plt.subplots(figsize=(14, max(3, len(inds) * 0.8)))
    im = ax.imshow(ari_masked, aspect='auto', cmap='RdYlGn', vmin=-0.3, vmax=0.5)

    ax.set_xticks(range(len(metrics)))
    ax.set_xticklabels(metrics, rotation=35, ha='right', fontsize=10)
    ax.set_yticks(range(len(inds)))
    ax.set_yticklabels(inds, fontsize=10)

    for i in range(len(inds)):
        for j in range(len(metrics)):
            d = dir_grid[i, j]
            star = '★' if pd.notna(p_grid[i,j]) and p_grid[i,j] < 0.05 else ''
            color = 'white' if (not np.isnan(ari_grid[i,j]) and abs(ari_grid[i,j]) > 0.25) else 'black'
            ax.text(j, i, f'{d}{star}', ha='center', va='center', fontsize=9, color=color)

    cbar = fig.colorbar(im, ax=ax, shrink=0.8)
    cbar.set_label('1-D KMeans ARI', fontsize=11)
    ax.set_title('Layer 1 — 1-D KMeans ARI per (indicator × metric)\n'
                 '(green=good separation, red=wrong separation, ★=p<0.05)',
                 fontsize=12, pad=10)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## §8 — Layer 2: continuous performance metrics
#
# Same analysis as Layer 1. These are PMU hardware counters and power/thermal
# readings. They are not hardware anomaly events — they are continuous metrics
# that deviate from normal when the hardware is under stress.
#
# The two new indicators (`uncore_imc/cas_count_read/write/`) measure DRAM
# transactions directly at the memory controller and are included here.

# %%
l2_results = analyse_indicator_group('Layer 2', HAT_L2, X_l2_raw)
print_summary_table(l2_results, 'Layer 2 — Continuous Performance Metrics')
l2_results.to_csv(RESULT_DIR / 'l2_results.csv', index=False)
# Out:
# ==========================================================================================
#   Layer 2 — Continuous Performance Metrics
# ==========================================================================================
#   Indicator                                Metric                 NonZero    p-value  Dir     ARI  Errors
#   -----------------------------------------------------------------------------------------------
#
#   uncore_imc/cas_count_read/               mean_rate              480/480    0.7540    ↑E  -0.000     240
#   uncore_imc/cas_count_read/               variance               480/480    0.0756    ↑E  -0.000     240
#   uncore_imc/cas_count_read/               p90_p10                480/480    0.0974    ↑E  -0.000     240
#   uncore_imc/cas_count_read/               slope                  480/480    0.0600    ↑E  -0.000     239
#   uncore_imc/cas_count_read/               spectral_entropy       480/480    0.6801    ↓E  -0.000     239
#   uncore_imc/cas_count_read/               burst_rate             480/480    0.2702    ↓E  -0.000     240
#   uncore_imc/cas_count_read/               burst_clustering       480/480    0.4712    ↑E  -0.000     235
#   uncore_imc/cas_count_read/               lz_complexity          480/480    0.9322    ↓E  -0.000     240
#   uncore_imc/cas_count_read/               perm_entropy           480/480    0.3901    ↑E  -0.001     238
#
#   uncore_imc/cas_count_write/              mean_rate              480/480    0.8516    ↑E  -0.001     239
#   uncore_imc/cas_count_write/              variance               480/480    0.6398    ↑E  -0.001     238
#   uncore_imc/cas_count_write/              p90_p10                480/480    0.7930    ↑E  -0.001     238
#   uncore_imc/cas_count_write/              slope                  480/480    0.3128    ↓E  -0.001     239
#   uncore_imc/cas_count_write/              spectral_entropy       480/480    0.4330    ↓E  -0.000     237
#   uncore_imc/cas_count_write/              burst_rate             480/480    0.5767    ↑E  -0.001     238
#   uncore_imc/cas_count_write/              burst_clustering       480/480    0.7409    ↑E  -0.000     237
#   uncore_imc/cas_count_write/              lz_complexity          480/480    0.9890    ↓E  -0.000     240
#   uncore_imc/cas_count_write/              perm_entropy           480/480    0.9797    ↑E   0.000     238
#
#   dTLB-load-misses                         mean_rate              480/480    0.0629    ↓E  -0.002     237
#   dTLB-load-misses                         variance               480/480    0.0663    ↓E  -0.000     230
#   dTLB-load-misses                         p90_p10                480/480    0.2313    ↓E  -0.002     237
#   dTLB-load-misses                         slope                  480/480    0.6335    ↑E  -0.002     236
#   dTLB-load-misses                         spectral_entropy       480/480    0.9892    ↓E  -0.002     237
#   dTLB-load-misses                         burst_rate             480/480    0.9441    ↓E  -0.001     237
#   dTLB-load-misses                         burst_clustering       480/480    0.0550    ↓E   0.000     228
#   dTLB-load-misses                         lz_complexity          480/480    0.5897    ↓E  -0.002     236
#   dTLB-load-misses                         perm_entropy           480/480    0.8644    ↑E  -0.001     238
#
#   cache-misses                             mean_rate              480/480    0.3499    ↓E  -0.002     238
#   cache-misses                             variance               480/480    0.5797    ↓E  -0.001     235
#   cache-misses                             p90_p10                480/480    0.4617    ↓E  -0.001     238
#   cache-misses                             slope                  480/480    0.3845    ↓E  -0.001     238
#   cache-misses                             spectral_entropy       480/480    0.2384    ↑E   0.000     228
#   cache-misses                             burst_rate             480/480    0.5398    ↓E  -0.001     232
#   cache-misses                             burst_clustering       480/480    0.3994    ↓E  -0.001     239
#   cache-misses                             lz_complexity          480/480    0.1601    ↑E  -0.000     240
#   cache-misses                             perm_entropy           480/480    0.2509    ↑E  -0.001     237
#
#   cache-references                         mean_rate              480/480    0.2883    ↓E   0.001     226
#   cache-references                         variance               480/480    0.7265    ↓E  -0.002     237
#   cache-references                         p90_p10                480/480    0.3816    ↓E  -0.002     239
#   cache-references                         slope                  480/480    0.2886    ↓E  -0.001     233
#   cache-references                         spectral_entropy       480/480    0.1299    ↑E   0.003     223
#   cache-references                         burst_rate             480/480    0.5556    ↓E   0.000     228
#   cache-references                         burst_clustering       480/480    0.3438    ↓E  -0.001     233
#   cache-references                         lz_complexity          480/480    0.1906    ↑E  -0.000     240
#   cache-references                         perm_entropy           480/480    0.0600    ↓E  -0.001     236
#
#   LLC-load-misses                          mean_rate              480/480    0.2218    ↓E  -0.002     239
#   LLC-load-misses                          variance               480/480    0.9378    ↑E  -0.000     231
#   LLC-load-misses                          p90_p10                480/480    0.8654    ↑E  -0.002     237
#   LLC-load-misses                          slope                  480/480    0.7329    ↓E  -0.002     239
#   LLC-load-misses                          spectral_entropy       480/480    0.9908    ↑E  -0.002     238
#   LLC-load-misses                          burst_rate             480/480    0.9646    ↑E  -0.002     239
#   LLC-load-misses                          burst_clustering       480/480    0.7870    ↑E  -0.002     240
#   LLC-load-misses                          lz_complexity          480/480    0.9877    ↑E  -0.002     240
#   LLC-load-misses                          perm_entropy           480/480    0.8181    ↓E   0.001     228
#
#   cycles                                   mean_rate              480/480    0.6976    ↓E  -0.002     237
#   cycles                                   variance               480/480    0.9577    ↑E  -0.001     239
#   cycles                                   p90_p10                480/480    0.6335    ↓E  -0.000     239
#   cycles                                   slope                  480/480    0.7359    ↑E   0.000     229
#   cycles                                   spectral_entropy       480/480    0.4009    ↑E  -0.002     238
#   cycles                                   burst_rate             480/480    0.4836    ↓E   0.001     227
#   cycles                                   burst_clustering       480/480    0.5381    ↓E  -0.000     240
#   cycles                                   lz_complexity          480/480    0.7805    ↓E  -0.000     239
#   cycles                                   perm_entropy           480/480    0.4968    ↑E  -0.002     239
#
#   instructions                             mean_rate              480/480    0.4943    ↓E  -0.001     238
#   instructions                             variance               480/480    0.1836    ↑E   0.000     230
#   instructions                             p90_p10                480/480    0.0302★   ↑E   0.003     223
#   instructions                             slope                  480/480    0.2466    ↓E   0.000     228
#   instructions                             spectral_entropy       480/480    0.4326    ↓E   0.007     218
#   instructions                             burst_rate             480/480    0.7399    ↓E  -0.000     239
#   instructions                             burst_clustering       480/480    0.0731    ↓E  -0.000     240
#   instructions                             lz_complexity          480/480    0.7073    ↓E  -0.000     239
#   instructions                             perm_entropy           480/480    0.5486    ↓E  -0.002     235
#
#   stalled-cycles-frontend                  —                        0/480         —     —       —       —
#
#   stalled-cycles-backend                   —                        0/480         —     —       —       —
#
#   branch-misses                            mean_rate              480/480    0.0657    ↓E   0.002     224
#   branch-misses                            variance               480/480    0.6260    ↑E  -0.002     235
#   branch-misses                            p90_p10                480/480    0.9221    ↑E  -0.001     233
#   branch-misses                            slope                  480/480    0.7157    ↓E  -0.001     236
#   branch-misses                            spectral_entropy       480/480    0.8566    ↑E  -0.001     233
#   branch-misses                            burst_rate             480/480    0.5312    ↓E  -0.002     238
#   branch-misses                            burst_clustering       480/480    0.3401    ↑E  -0.002     236
#   branch-misses                            lz_complexity          480/480    0.9274    ↑E  -0.001     234
#   branch-misses                            perm_entropy           480/480    0.9698    ↓E  -0.001     238
#
#   branch-instructions                      mean_rate              480/480    0.0269★   ↓E  -0.001     231
#   branch-instructions                      variance               480/480    0.6121    ↑E  -0.001     234
#   branch-instructions                      p90_p10                480/480    0.5689    ↓E  -0.002     239
#   branch-instructions                      slope                  480/480    0.8929    ↑E   0.000     229
#   branch-instructions                      spectral_entropy       480/480    0.9467    ↓E  -0.002     237
#   branch-instructions                      burst_rate             480/480    0.3492    ↓E   0.000     229
#   branch-instructions                      burst_clustering       480/480    0.2445    ↓E  -0.001     231
#   branch-instructions                      lz_complexity          480/480    0.7800    ↓E  -0.001     234
#   branch-instructions                      perm_entropy           480/480    0.4372    ↓E  -0.000     234
#
#   power/energy-pkg/                        mean_rate              480/480    0.3805    ↓E  -0.001     235
#   power/energy-pkg/                        variance               480/480    0.7795    ↑E  -0.001     240
#   power/energy-pkg/                        p90_p10                480/480    0.3037    ↑E  -0.001     231
#   power/energy-pkg/                        slope                  480/480    0.9903    ↑E  -0.000     230
#   power/energy-pkg/                        spectral_entropy       480/480    0.9378    ↑E  -0.000     239
#   power/energy-pkg/                        burst_rate             480/480    0.5865    ↓E  -0.002     235
#   power/energy-pkg/                        burst_clustering       480/480    0.9903    ↓E  -0.002     238
#   power/energy-pkg/                        lz_complexity          480/480    0.6748    ↓E   0.000     228
#   power/energy-pkg/                        perm_entropy           480/480    0.9604    ↓E  -0.001     234
#
#   power/energy-ram/                        mean_rate              480/480    0.4673    ↓E   0.001     227
#   power/energy-ram/                        variance               480/480    0.9913    ↑E  -0.001     236
#   power/energy-ram/                        p90_p10                480/480    0.9853    ↑E  -0.001     233
#   power/energy-ram/                        slope                  480/480    0.4116    ↓E  -0.002     240
#   power/energy-ram/                        spectral_entropy       480/480    0.8623    ↑E  -0.001     238
#   power/energy-ram/                        burst_rate             480/480    0.5556    ↓E  -0.002     238
#   power/energy-ram/                        burst_clustering       480/480    0.6743    ↓E  -0.002     236
#   power/energy-ram/                        lz_complexity          480/480    0.7181    ↓E  -0.002     239
#   power/energy-ram/                        perm_entropy           480/480    0.9756    ↓E  -0.002     238
#
#   msr/cpu_thermal_margin/                  mean_rate              480/480    0.0048★   ↓E  -0.000     231
#   msr/cpu_thermal_margin/                  variance               480/480    0.4399    ↑E   0.001     232
#   msr/cpu_thermal_margin/                  p90_p10                480/480    0.4472    ↑E   0.001     232
#   msr/cpu_thermal_margin/                  slope                  480/480    0.2620    ↑E   0.003     227
#   msr/cpu_thermal_margin/                  spectral_entropy       480/480    0.0964    ↓E   0.013     211
#   msr/cpu_thermal_margin/                  burst_rate             480/480    0.1131    ↓E   0.001     227
#   msr/cpu_thermal_margin/                  burst_clustering       480/480    0.3823    ↓E   0.004     221
#   msr/cpu_thermal_margin/                  lz_complexity          480/480    0.9515    ↑E  -0.002     238
#   msr/cpu_thermal_margin/                  perm_entropy           480/480    0.8654    ↑E  -0.002     238

# %% [markdown]
# ### §8a — Layer 2: top features by 1-D KMeans ARI

# %%
# Bar chart: top 20 Layer 2 (indicator, metric) pairs by ARI
l2_top = (l2_results
          .dropna(subset=['ari'])
          .sort_values('ari', ascending=False)
          .head(20)
          .reset_index(drop=True))

fig, ax = plt.subplots(figsize=(12, 6))
colors = ['firebrick' if r['direction'] == '↑E' else 'steelblue'
          for _, r in l2_top.iterrows()]
bars = ax.barh(range(len(l2_top)), l2_top['ari'], color=colors, alpha=0.8)

for i, (_, row) in enumerate(l2_top.iterrows()):
    star = '★' if pd.notna(row['p']) and row['p'] < 0.05 else ''
    ax.text(max(row['ari'] + 0.005, 0.01), i,
            f"{row['indicator']}__{row['metric']}  {star}",
            va='center', fontsize=9)

ax.set_yticks(range(len(l2_top)))
ax.set_yticklabels([f"{r['direction']}" for _, r in l2_top.iterrows()], fontsize=9)
ax.set_xlabel('1-D KMeans ARI (higher = better separation)', fontsize=11)
ax.axvline(0, color='black', lw=0.8)
ax.invert_yaxis()
ax.spines[['top','right']].set_visible(False)

n_patch = mpatches.Patch(color='steelblue', label='↓E (lower in emotional)')
e_patch = mpatches.Patch(color='firebrick', label='↑E (higher in emotional)')
ax.legend(handles=[n_patch, e_patch], fontsize=9)
plt.title('Layer 2 — top 20 features by 1-D KMeans ARI', fontsize=12)
plt.tight_layout()
plt.show()

print(f'\nSignificant (p<0.05): {(l2_results.p < 0.05).sum()} / {l2_results.p.notna().sum()} tested')
# Out:
# Significant (p<0.05): 3 / 117 tested

# %% [markdown]
# ### §8b — Layer 2: heatmap (indicator × metric)

# %%
l2_ok = l2_results[l2_results.status.ne('NOT IN DATA') & l2_results.status.ne('ALL ZERO')].copy()

if not l2_ok.empty:
    inds    = l2_ok['indicator'].unique().tolist()
    metrics = ALL_METRICS
    ari_grid = np.full((len(inds), len(metrics)), np.nan)
    dir_grid = np.full((len(inds), len(metrics)), '—', dtype=object)
    p_grid   = np.full((len(inds), len(metrics)), np.nan)

    for _, row in l2_ok.iterrows():
        if row['metric'] in metrics:
            i = inds.index(row['indicator'])
            j = metrics.index(row['metric'])
            ari_grid[i, j] = row['ari'] if pd.notna(row['ari']) else np.nan
            dir_grid[i, j] = row['direction']
            p_grid[i, j]   = row['p']

    ari_masked = np.ma.masked_invalid(ari_grid)
    fig, ax = plt.subplots(figsize=(14, max(4, len(inds) * 0.65)))
    im = ax.imshow(ari_masked, aspect='auto', cmap='Greys', vmin=-0.3, vmax=0.5)

    ax.set_xticks(range(len(metrics)))
    ax.set_xticklabels(metrics, rotation=35, ha='right', fontsize=9)
    ax.set_yticks(range(len(inds)))
    ax.set_yticklabels(inds, fontsize=9)

    for i in range(len(inds)):
        for j in range(len(metrics)):
            d = dir_grid[i, j]
            star = '★' if pd.notna(p_grid[i,j]) and p_grid[i,j] < 0.05 else ''
            color = 'white' if (not np.isnan(ari_grid[i,j]) and abs(ari_grid[i,j]) > 0.25) else 'black'
            ax.text(j, i, f'{d}{star}', ha='center', va='center', fontsize=8, color=color)

    fig.colorbar(im, ax=ax, shrink=0.8).set_label('1-D KMeans ARI', fontsize=10)
    ax.set_title('Layer 2 — 1-D KMeans ARI per (indicator × metric)', fontsize=12, pad=10)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## §9 — Confounders (shown separately, not used in clustering)
#
# These are collected for context but should not be interpreted as substrate signals.
# If a confounder differs significantly between conditions, it may explain some of the
# signal seen in L1/L2 features.

# %%
cf_results = analyse_indicator_group('Confounders', CONFOUNDERS, X_cf_raw)
print_summary_table(cf_results, 'Confounders — informational only, not used in clustering')

# Flag any significant confounders
sig_cf = cf_results[cf_results.p < 0.05]
if not sig_cf.empty:
    print(f'\n⚠  Significant confounders (p<0.05) — interpret L1/L2 results with caution:')
    for _, r in sig_cf.iterrows():
        print(f'   {r["indicator"]}__{r["metric"]}  p={r["p"]:.4f}  {r["direction"]}')
else:
    print('\n✓  No significant confounders.')
# Out:
# ==========================================================================================
#   Confounders — informational only, not used in clustering
# ==========================================================================================
#   Indicator                                Metric                 NonZero    p-value  Dir     ARI  Errors
#   -----------------------------------------------------------------------------------------------
#
#   context-switches                         mean_rate              480/480    0.2989    ↓E  -0.000     231
#   context-switches                         variance               480/480    0.6676    ↓E  -0.002     239
#   context-switches                         p90_p10                480/480    0.4703    ↓E  -0.002     239
#   context-switches                         slope                  480/480    0.5204    ↓E  -0.001     235
#   context-switches                         spectral_entropy       480/480    0.3699    ↑E  -0.001     237
#   context-switches                         burst_rate             480/480    0.3546    ↓E  -0.001     233
#   context-switches                         burst_clustering       480/480    0.5286    ↓E  -0.002     236
#   context-switches                         lz_complexity          480/480    0.7329    ↑E  -0.001     237
#   context-switches                         perm_entropy           480/480    0.2091    ↓E   0.002     224
#
#   cpu-migrations                           mean_rate              480/480    0.1981    ↓E  -0.002     240
#   cpu-migrations                           variance               480/480    0.5712    ↓E  -0.002     240
#   cpu-migrations                           p90_p10                480/480    0.3775    ↓E  -0.002     240
#   cpu-migrations                           slope                  480/480    0.7024    ↓E  -0.002     240
#   cpu-migrations                           spectral_entropy       480/480    0.2504    ↑E  -0.002     239
#   cpu-migrations                           burst_rate             480/480    0.9426    ↑E  -0.002     239
#   cpu-migrations                           burst_clustering       480/480    0.7029    ↓E  -0.001     239
#   cpu-migrations                           lz_complexity          480/480    0.7243    ↓E  -0.001     237
#   cpu-migrations                           perm_entropy           480/480    0.2542    ↓E  -0.002     239
#
#   page-faults                              mean_rate              480/480    0.0060★   ↓E   0.009     215
#   page-faults                              variance               480/480    0.1090    ↓E   0.001     227
#   page-faults                              p90_p10                467/480    0.0045★   ↓E   0.005     221
#   page-faults                              slope                  480/480    0.6671    ↑E  -0.002     237
#   page-faults                              spectral_entropy       480/480    0.9945    ↑E  -0.002     238
#   page-faults                              iat_cv                 480/480    0.5486    ↑E  -0.000     236
#   page-faults                              burst_rate             480/480    0.5974    ↑E   0.000     239
#   page-faults                              burst_clustering       480/480    0.8711    ↑E   0.003     223
#   page-faults                              lz_complexity          480/480    0.9436    ↓E   0.001     226
#   page-faults                              perm_entropy           480/480    0.0743    ↓E   0.005     221
#
#   cpu-clock                                mean_rate              480/480    0.6130    ↓E   0.001     228
#   cpu-clock                                variance               480/480    0.5530    ↑E  -0.002     238
#   cpu-clock                                p90_p10                480/480    0.1753    ↑E   0.002     224
#   cpu-clock                                slope                  480/480    0.9714    ↓E  -0.001     234
#   cpu-clock                                spectral_entropy       480/480    0.6883    ↑E   0.000     229
#   cpu-clock                                burst_rate             480/480    0.5951    ↓E  -0.002     236
#   cpu-clock                                burst_clustering       480/480    0.7972    ↓E  -0.002     236
#   cpu-clock                                lz_complexity          480/480    0.7314    ↓E  -0.001     232
#   cpu-clock                                perm_entropy           480/480    0.5901    ↑E  -0.002     237
#
#   cpu_freq_mean                            mean_rate              480/480    0.2122    ↓E  -0.001     234
#   cpu_freq_mean                            variance               480/480    0.9039    ↑E  -0.002     237
#   cpu_freq_mean                            p90_p10                480/480    0.6903    ↑E  -0.002     235
#   cpu_freq_mean                            slope                  480/480    0.3202    ↑E   0.000     231
#   cpu_freq_mean                            spectral_entropy       480/480    0.7603    ↓E  -0.000     238
#   cpu_freq_mean                            burst_rate             261/480    0.4678    ↑E  -0.002     235
#   cpu_freq_mean                            burst_clustering       261/480    0.3473    ↑E   0.000     229
#   cpu_freq_mean                            lz_complexity          480/480    0.7578    ↓E  -0.001     239
#   cpu_freq_mean                            perm_entropy           480/480    0.6674    ↑E  -0.001     238
#
# ⚠  Significant confounders (p<0.05) — interpret L1/L2 results with caution:
#    page-faults__mean_rate  p=0.0060  ↓E
#    page-faults__p90_p10  p=0.0045  ↓E

# %% [markdown]
# ## §10 — Combined ranking: L1 + L2
#
# Composite rank = average of p-value rank and ARI rank across all L1 + L2 features.
# This identifies the top candidates for the multi-feature clustering in §11.

# %%
combined = pd.concat([
    l1_results[l1_results.status.ne('NOT IN DATA') & l1_results.status.ne('ALL ZERO')],
    l2_results[l2_results.status.ne('NOT IN DATA') & l2_results.status.ne('ALL ZERO')],
], ignore_index=True).dropna(subset=['p', 'ari'])

# Rank by p (ascending = better) and ARI (descending = better)
combined['p_rank']   = combined['p'].rank(ascending=True)
combined['ari_rank'] = combined['ari'].rank(ascending=False)
combined['comp_rank'] = (combined['p_rank'] + combined['ari_rank']) / 2
combined = combined.sort_values('comp_rank').reset_index(drop=True)

print(f'Combined L1+L2 ranking — top {min(30, len(combined))} features:')
print(f'  {"Rank":<5} {"Layer":<7} {"Feature":<55} {"p-value":>10} {"ARI":>8} {"Dir":>4} {"Errors":>7}')
print(f'  {"-"*95}')
for i, (_, row) in enumerate(combined.head(30).iterrows()):
    layer = 'L1' if row['indicator'] in HAT_L1 else 'L2'
    feat  = f"{row['indicator']}__{row['metric']}"
    star  = '★' if row['p'] < 0.05 else ' '
    err   = f"{int(row['n_errors'])}" if pd.notna(row['n_errors']) else '—'
    print(f"  {i+1:<5} {layer:<7} {feat:<55} {row['p']:>9.4f}{star} {row['ari']:>8.3f} {row['direction']:>4} {err:>7}")

combined.to_csv(RESULT_DIR / 'combined_ranking.csv', index=False)
# Out:
# Combined L1+L2 ranking — top 30 features:
#   Rank  Layer   Feature                                                    p-value      ARI  Dir  Errors
#   -----------------------------------------------------------------------------------------------
#   1     L2      instructions__p90_p10                                      0.0302★    0.003   ↑E     223
#   2     L1      tlb:tlb_flush__burst_clustering                            0.0736     0.003   ↓E     223
#   3     L2      branch-misses__mean_rate                                   0.0657     0.002   ↓E     224
#   4     L2      msr/cpu_thermal_margin/__spectral_entropy                  0.0964     0.013   ↓E     211
#   5     L1      core_power.throttle__mean_rate                             0.0929     0.006   ↓E     219
#   6     L1      hat_TLB__mean_rate                                         0.0593     0.001   ↓E     227
#   7     L1      core_power.throttle__spectral_entropy                      0.1292     0.005   ↑E     220
#   8     L1      tlb:tlb_flush__slope                                       0.0773     0.001   ↑E     227
#   9     L2      cache-references__spectral_entropy                         0.1299     0.003   ↑E     223
#   10    L2      dTLB-load-misses__burst_clustering                         0.0550     0.000   ↓E     228
#   11    L1      tlb:tlb_flush__mean_rate                                   0.0312★    0.000   ↓E     229
#   12    L2      msr/cpu_thermal_margin/__burst_rate                        0.1131     0.001   ↓E     227
#   13    L2      msr/cpu_thermal_margin/__slope                             0.2620     0.003   ↑E     227
#   14    L2      uncore_imc/cas_count_read/__slope                          0.0600    -0.000   ↑E     239
#   15    L2      cache-references__mean_rate                                0.2883     0.001   ↓E     226
#   16    L2      msr/cpu_thermal_margin/__burst_clustering                  0.3823     0.004   ↓E     221
#   17    L2      msr/cpu_thermal_margin/__mean_rate                         0.0048★   -0.000   ↓E     231
#   18    L2      instructions__variance                                     0.1836     0.000   ↑E     230
#   19    L2      instructions__burst_clustering                             0.0731    -0.000   ↓E     240
#   20    L2      cache-misses__spectral_entropy                             0.2384     0.000   ↑E     228
#   21    L2      uncore_imc/cas_count_read/__variance                       0.0756    -0.000   ↑E     240
#   22    L2      instructions__spectral_entropy                             0.4326     0.007   ↓E     218
#   23    L1      hat_SPU__lz_complexity                                     0.1858     0.000   ↓E     229
#   24    L1      hat_MCE__lz_complexity                                     0.1858     0.000   ↓E     229
#   25    L1      tlb:tlb_flush__p90_p10                                     0.1588     0.000   ↓E     239
#   26    L2      instructions__slope                                        0.2466     0.000   ↓E     228
#   27    L1      core_power.throttle__lz_complexity                         0.0903    -0.000   ↑E     240
#   28    L2      dTLB-load-misses__variance                                 0.0663    -0.000   ↓E     230
#   29    L1      core_power.throttle__burst_rate                            0.2967     0.001   ↓E     227
#   30    L1      hat_TLB__lz_complexity                                     0.2929     0.001   ↑E     228

# %% [markdown]
# ## §11 — Multi-feature clustering: top-N features (L1 + L2, no confounders)
#
# We take the top **TOP_N** features by composite rank and run k=2 KMeans on
# the combined feature matrix. The question: does combining features improve
# cluster separation beyond what any single feature achieves alone?
#
# TOP_N is set in §2. Currently: `TOP_N = {TOP_N}`

# %%
# Build the combined feature matrix for top-N features
top_features = combined.head(TOP_N)['col'].dropna().tolist()
top_features = [f for f in top_features if f in X_l1_raw.columns or f in X_l2_raw.columns]

# Merge L1 and L2 raw into one frame for the top features
all_raw = pd.concat([X_l1_raw, X_l2_raw], axis=1)
# Keep only top features that exist
top_features = [f for f in top_features if f in all_raw.columns]

print(f'Top {TOP_N} features selected for n-D clustering:')
for i, f in enumerate(top_features):
    layer = 'L1' if indicator_of(f) in HAT_L1 else 'L2'
    print(f'  {i+1}. [{layer}] {f}')

X_top_raw = all_raw[top_features].apply(pd.to_numeric, errors='coerce').fillna(all_raw[top_features].median())
scaler_top = StandardScaler()
X_top = scaler_top.fit_transform(X_top_raw)

# K-sweep: silhouette to validate k=2
from sklearn.metrics import silhouette_score
k_range = range(1, 8)
inertias, silhouettes = [], []
for k in k_range:
    km = KMeans(n_clusters=k, n_init=20, random_state=42).fit(X_top)
    inertias.append(km.inertia_)
    silhouettes.append(silhouette_score(X_top, km.labels_) if k > 1 else np.nan)

best_k = list(k_range)[int(np.nanargmax(silhouettes))]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(list(k_range), inertias, marker='o', color='steelblue')
axes[0].set_xticks(list(k_range))
axes[0].set_xlabel('k'); axes[0].set_ylabel('Inertia (WCSS)')
axes[0].set_title('Elbow method')

axes[1].plot(list(k_range)[1:], silhouettes[1:], marker='o', color='firebrick')
axes[1].axvline(best_k, color='firebrick', lw=0.8, ls=':', label=f'Best k={best_k}')
axes[1].set_xticks(list(k_range)[1:])
axes[1].set_xlabel('k'); axes[1].set_ylabel('Silhouette score')
axes[1].set_title(f'Silhouette — favours k={best_k}')
axes[1].legend(fontsize=9)
plt.suptitle(f'K-sweep on top {TOP_N} features', fontsize=12)
plt.tight_layout()
plt.show()

if best_k == 2:
    print('✓ Silhouette favours k=2 — two-cluster assumption is supported.')
else:
    print(f'⚠ Silhouette favours k={best_k} — consider adjusting TOP_N or feature selection.')
# Out:
# Top 4 features selected for n-D clustering:
#   1. [L2] instructions__p90_p10
#   2. [L1] tlb:tlb_flush__burst_clustering
#   3. [L2] branch-misses__mean_rate
#   4. [L2] msr/cpu_thermal_margin/__spectral_entropy
# ⚠ Silhouette favours k=4 — consider adjusting TOP_N or feature selection.

# %% [markdown]
# ### §11a — n-D KMeans k=2 result

# %%
km_nd = KMeans(n_clusters=2, n_init=50, random_state=42).fit(X_top)
labels_nd = km_nd.labels_

ari_nd  = adjusted_rand_score(y, labels_nd)
cm_nd   = confusion_matrix(y, labels_nd)
acc1    = (cm_nd[0,0] + cm_nd[1,1]) / cm_nd.sum()
acc2    = (cm_nd[0,1] + cm_nd[1,0]) / cm_nd.sum()
acc_nd  = max(acc1, acc2)
n_err_nd = int(round((1 - acc_nd) * len(y)))

print(f'n-D KMeans k=2 f top {TOP_N} features:')
print(f'  ARI            : {ari_nd:.4f}')
print(f'  Accuracy       : {acc_nd:.4f}  ({n_err_nd} errors out of {len(y)})')
print(f'  Best 1-D ARI   : {combined.ari.max():.4f}  (single feature baseline)')
print(f'  Improvement    : {ari_nd - combined.ari.max():.4f}')

# PCA scatter
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_top)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, labels, title in [
        (axes[0], y,        'Ground truth (neutral=blue, emotional=red)'),
        (axes[1], labels_nd, f'KMeans k=2 (ARI={ari_nd:.3f}, errors={n_err_nd})')]:
    colors = ['steelblue' if l == 0 else 'firebrick' for l in labels]
    ax.scatter(X_pca[:, 0], X_pca[:, 1], c=colors, alpha=0.6, s=25)
    ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]*100:.1f}%)')
    ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]*100:.1f}%)')
    ax.set_title(title, fontsize=11)
    ax.spines[['top','right']].set_visible(False)

n_p = mpatches.Patch(color='steelblue', label='Neutral')
e_p = mpatches.Patch(color='firebrick', label='Emotional')
fig.legend(handles=[n_p, e_p], loc='upper right', fontsize=10)
plt.suptitle(f'PCA of top {TOP_N} features — 2D projection', fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# n-D KMeans k=2 f top 4 features:
#   ARI            : 0.0137
#   Accuracy       : 0.5625  (210 errors out of 480)
#   Best 1-D ARI   : 0.0125  (single feature baseline)
#   Improvement    : 0.0011

# %% [markdown]
# ### §11b — K-sweep: how does ARI scale with N features?

# %%
# Sweep K from 1 to min(15, available) — how many features do we need?
all_cols_ranked = combined['col'].dropna().tolist()
all_cols_ranked = [c for c in all_cols_ranked if c in all_raw.columns]
K_max = min(15, len(all_cols_ranked))

K_vals, ari_vals, err_vals = [], [], []
for K in range(1, K_max + 1):
    cols_K = all_cols_ranked[:K]
    X_K = all_raw[cols_K].apply(pd.to_numeric, errors='coerce').fillna(all_raw[cols_K].median())
    X_K = StandardScaler().fit_transform(X_K)
    km  = KMeans(n_clusters=2, n_init=20, random_state=42).fit(X_K)
    ari = adjusted_rand_score(y, km.labels_)
    cm  = confusion_matrix(y, km.labels_)
    acc = max((cm[0,0]+cm[1,1])/cm.sum(), (cm[0,1]+cm[1,0])/cm.sum())
    K_vals.append(K); ari_vals.append(ari); err_vals.append(int(round((1-acc)*len(y))))

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(K_vals, ari_vals, marker='o', color='steelblue')
axes[0].axvline(TOP_N, color='orange', lw=1.5, ls='--', label=f'TOP_N={TOP_N}')
axes[0].set_xlabel('Number of features (K)')
axes[0].set_ylabel('KMeans ARI')
axes[0].set_title('ARI vs number of features')
axes[0].legend(fontsize=9)

axes[1].plot(K_vals, err_vals, marker='o', color='firebrick')
axes[1].axvline(TOP_N, color='orange', lw=1.5, ls='--', label=f'TOP_N={TOP_N}')
axes[1].set_xlabel('Number of features (K)')
axes[1].set_ylabel('Clustering errors')
axes[1].set_title('Errors vs number of features')
axes[1].legend(fontsize=9)

plt.suptitle('n-D KMeans k=2 — feature sweep (L1+L2, composite rank order)', fontsize=12)
plt.tight_layout()
plt.show()

print('K-sweep results:')
for K, ari, err in zip(K_vals, ari_vals, err_vals):
    marker = ' ← TOP_N' if K == TOP_N else ''
    print(f'  K={K:2d}  ARI={ari:.4f}  errors={err}{marker}')
# Out:
# K-sweep results:
#   K= 1  ARI=0.0030  errors=223
#   K= 2  ARI=0.0030  errors=223
#   K= 3  ARI=0.0018  errors=225
#   K= 4  ARI=0.0137  errors=210 ← TOP_N
#   K= 5  ARI=-0.0002  errors=230
#   K= 6  ARI=0.0019  errors=225
#   K= 7  ARI=0.0042  errors=221
#   K= 8  ARI=0.0032  errors=223
#   K= 9  ARI=0.0031  errors=223
#   K=10  ARI=0.0051  errors=220
#   K=11  ARI=0.0031  errors=223
#   K=12  ARI=0.0015  errors=226
#   K=13  ARI=0.0020  errors=225
#   K=14  ARI=0.0020  errors=225
#   K=15  ARI=0.0020  errors=225

# %% [markdown]
# ## §12 — Summary

# %%
print('='*80)
print('ANALYSIS SUMMARY')
print('='*80)
print(f'Trials: {len(df_all)} ({len(RUNS_LOADED)} runs)')
print(f'Elapsed_ms balanced: {"YES" if not LENGTH_CONFOUNDED else "NO — length confound present"}')
print()

print('Layer 1 — HAT Hardware Anomaly Indicators:')
for ind, desc in HAT_L1.items():
    ind_cols = [c for c in X_l1_raw.columns if indicator_of(c) == ind or c.startswith(ind+'__')]
    if not ind_cols:
        print(f'  {ind:<45} NOT IN DATA')
        continue
    any_nz = (X_l1_raw[ind_cols].apply(pd.to_numeric,errors='coerce').abs()>1e-9).any(axis=1).sum()
    best = l1_results[l1_results.indicator == ind].dropna(subset=['p']).sort_values('p')
    if best.empty or any_nz == 0:
        print(f'  {ind:<45} ALL ZERO (healthy node)')
    else:
        r = best.iloc[0]
        star = '★' if r.p < 0.05 else ''
        print(f'  {ind:<45} non-zero={any_nz}/{len(df_all)}  best: {r.metric}  p={r.p:.4f}{star}  ARI={r.ari:.3f}  {r.direction}')

print()
print('Layer 2 — top 5 features:')
for i, (_, row) in enumerate(combined[combined.indicator.isin(HAT_L2)].head(5).iterrows()):
    star = '★' if row.p < 0.05 else ''
    print(f'  {i+1}. {row.indicator}__{row.metric}  p={row.p:.4f}{star}  ARI={row.ari:.3f}  {row.direction}')

print()
print(f'Multi-feature KMeans (top {TOP_N}):')
print(f'  ARI = {ari_nd:.4f}   accuracy = {acc_nd:.4f}   errors = {n_err_nd}/{len(y)}')
print(f'  Best single-feature ARI = {combined.ari.max():.4f}')
print(f'  Gain from combining features = {ari_nd - combined.ari.max():.4f}')
# Out:
# ================================================================================
# ANALYSIS SUMMARY
# ================================================================================
# Trials: 480 (12 runs)
# Elapsed_ms balanced: YES
#
# Layer 1 — HAT Hardware Anomaly Indicators:
#   hat_SPU                                       non-zero=480/480  best: lz_complexity  p=0.1858  ARI=0.000  ↓E
#   hat_MCE                                       non-zero=480/480  best: lz_complexity  p=0.1858  ARI=0.000  ↓E
#   hat_TLB                                       non-zero=480/480  best: mean_rate  p=0.0593  ARI=0.001  ↓E
#   tlb:tlb_flush                                 non-zero=480/480  best: mean_rate  p=0.0312★  ARI=0.000  ↓E
#   mce:mce_record                                non-zero=480/480  best: lz_complexity  p=0.5956  ARI=-0.002  ↓E
#   core_power.throttle                           non-zero=480/480  best: slope  p=0.0466★  ARI=-0.000  ↓E
#   uncore_imc/UNC_M_ECC_CORRECTABLE_ERRORS/      non-zero=480/480  best: lz_complexity  p=0.5170  ARI=-0.000  ↑E
#
# Layer 2 — top 5 features:
#   1. instructions__p90_p10  p=0.0302★  ARI=0.003  ↑E
#   2. branch-misses__mean_rate  p=0.0657  ARI=0.002  ↓E
#   3. msr/cpu_thermal_margin/__spectral_entropy  p=0.0964  ARI=0.013  ↓E
#   4. cache-references__spectral_entropy  p=0.1299  ARI=0.003  ↑E
#   5. dTLB-load-misses__burst_clustering  p=0.0550  ARI=0.000  ↓E
#
# Multi-feature KMeans (top 4):
#   ARI = 0.0137   accuracy = 0.5625   errors = 210/480
#   Best single-feature ARI = 0.0125
#   Gain from combining features = 0.0011
